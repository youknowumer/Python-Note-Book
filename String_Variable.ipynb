# %%
a=76
sname="Ali"
address= "23 Multan road ,Lahore"
Grade = 'B+'

print(a)
print("sname, address")
# Out:
# 76
# sname, address

# %%
print(sname[1])
for x in sname:
 print(x)
# Out:
# l
# A
# l
# i

# %%
print(len(sname))
# Out:
# 3

# %%
print(len(address))
# Out:
# 22

# %%
print(sname.upper())
print(sname.lower())
# Out:
# ALI
# ali

# %%
print(address)
# Out:
# 23 Multan road ,Lahore

# %%
print(address.replace('k','d'))
# Out:
# 23 Multan road ,Lahore

# %%
print(address.replace('o','e'))
# Out:
# 23 Multan read ,Lahere

# %%
print(address.replace('Lahore','Karachi'))
# Out:
# 23 Multan road ,Karachi

# %%
address = (address.replace('Lahore','Karachi'))
print(address)
# Out:
# 23 Multan road ,Karachi

# %%
grades = [ "A" , "B" , "C" , "D" ]
print(grades[2])
for x in grades:
 print(x)
# Out:
# C
# A
# B
# C
# D

# %%
x1= 'english'
x2= 'chemistry'
x3= 'math'
x4= 'pf'
for x in grades:
 if x == "x1":
  print(x, "Excellent")
 elif x == "x2":
  print(x, "Good")
 elif x == "x3":
  print(x, "Hardworking")
 elif x == "x4":
  print(x, "Work more and more")
 else:
  print(x,"much effort required")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1ab2719b55ca> in <cell line: 2>()
#       1 x= ("chemistry , math , physics ,english")
# ----> 2 for x in grades:
#       3  if x == "chemistry":
#       4   print(x, "Excellent")
#       5  elif x == "math":
#
# NameError: name 'grades' is not defined

# %%
x = ("chemistry , math , english")
x= (input("Please enter a letter grade: "))
if grade >= A:
    grade == "4.0"
elif grade < A:
      grade < "4.0"
print(grade)
# Out:
# Please enter a letter grade: A
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-40d9edaeca47> in <cell line: 3>()
#       1 x = ("chemistry , math , english")
#       2 x= (input("Please enter a letter grade: "))
# ----> 3 if grade >= A:
#       4     grade == "4.0"
#       5 elif grade < A:
#
# NameError: name 'grade' is not defined

# %%
a = [' Umer.a']
a.append('zaheeb')
