# %%
print("volume")
# Out:
# volume

# %%
def volume(x, y, z):
    volume = x * y * z
    return volume

# %%
x = 223
y = 323
z = 434
result = volume(x, y, z)
print("volume:", result)
# Out:
# volume: 31260586

# %%
def hours2min(hour):
  return hour/60
  
totalminutes=hours2min(70)+hours2min(50)+hours2min(20)
print("totalminuts",totalminutes)
# Out:
# totalminuts 2.3333333333333335
