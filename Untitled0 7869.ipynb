# %%
row=2
while row<=10:
  coulumn = row
  while coulumn <= row + 8:
     Print(coulumn, end ="")
       column += 2:
  print()
  row+=2
# Out:
#   File "<ipython-input-14-a69e674eda6b>", line 6
#     column += 2:
#     ^
# IndentationError: unexpected indent

# %%
for a in range (3):
 for num in range(1, 5):
  print(num,end=" "())
 print()
