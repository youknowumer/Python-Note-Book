# %%
class cube:
      print("volume is ",self.width*self.height*self.length)
      def __init__(self, width, height,length):
  self.width=width
  self.height=height
  self.length=length
def cube(self):
  print("volume is ",self.width*self.height*self.length)

# %%
c=(5,7)
c1=(6,8)

# %%
c.cube()
c1.cube()

# %%
class cube:
      def __init__(self, width, height,length):
        self.width=width
        self.height=height
        self.length=length
def cube(self):
  print("volume is ",self.width*self.height*self.length)
def shape(self):
  if(self.width==self.height and self.width==self.length and self.height==self.length):
    print("Cube")
  else:
    print("Bar")

# %%
c=(2,2,2)
