# %%
class box:
  def area(self):
      print("Area is ",self.width*self.height)
  def __init__(self, width, height):
    self.width=width
    self.height=height

# %%
b=box(5, 6)
b2=box(3, 8)
b3=box(5, 9)

# %%
b.area()
b2.area()
b3.area()
# Out:
# Area is  30
# Area is  24
# Area is  45
